# %% [markdown]
# # NASHVILLE BIKESHARE TRIP DATA ANALYSIS
#
#
# ###  Written by: Damilola Olaleye

# %% [markdown]
# ### INTRODUCTION
# I observed that there is a sudden increase in the bike usage at this time of the year as most
# of the Bikes located at the Foy Center gets checked out quite often, although we were not
# able to get the Clarksville bikeshare data, but this inspired our interest in analysing the
# Nashville bikeshare data we got, due to the fact that we both have riding bicycle for an
# hobby.
#
# ### DATA COLLECTION
# I collected the dataset from Mr. Kenneth Abbott who is a Managing Director at Morgan
# Stanley for over 20 years and an Adjunct Professor at NYU. We had a symposium in the
# department sometime ago and he explained about maximizing predictive analytics to solving
# real life issues. He then explained that he had access to the Nashville Bikeshare data which
# was given to him from a reliable source and we contacted him for the data to apply the
# knowledge acquired in the Python for Data Science to analyse the data.
# The data consists of 233,212 observations and 35 features, the link to the dataset is attached
# in this link https://drive.google.com/file/d/1TcPy1Ot32pNxz4KK5reM72tmAtgAQ-Y8/view.
#
# ### OBJECTIVES:
#
# I would like to categorize our questions in two-tiers;
#
# First, as a business consultant to make smarter decisions that saves cost, maximize profit and customer satisfaction.
#
# *  What are the checkout and return kiosks with highest usage rate?
# *  What is the average trip duration?
# *  For an annual award ceremony, we like to know the top 20 users with highest trip duration.
# *  What is the average calories burned?
# *  What day of the week has highest pickup rate?
# *  What season of the year has the highest trip duration?
#
#     Secondly, as a user or customer of the bike-share service, what are the factors that might
#     influence the usage of the service.
# *  What time of the day has the highest pickup rate?
# *  What is the statistics of the zip codes with kiosk present?
# *  WWhat is the statictic of membershipType used by riders
# *  What is the average carbon offset as a result riding?

# %% [markdown]
# <img src="https://c8.alamy.com/comp/F0N0XX/b-cycle-bike-sharing-program-bicycles-docked-at-the-cumberland-park-F0N0XX.jpg">

# %% [markdown]
# ### Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading the data
#
# I would be reading the bikeData which is a CSV file with pandas into data so that it can be readily available in memory for data analysis.

# %%
data = pd.read_csv("bikeData3.csv")
# Out:
# C:\Users\HP Laptop\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# I observed that the data kept reading some empty spaces and filled some rows with NaN, so
# I decided to use this method to read the rows that contains data

# %%
data=data[:233212]
data = pd.DataFrame(data)
data
# Out:
#             TripId    UserProgramName     UserId              UserRole  \
# 0        8270269.0  Nashville B-cycle  1051761.0  Non-RFID Card Member
# 1        8270272.0  Nashville B-cycle  1051761.0  Non-RFID Card Member
# 2        8270469.0  Nashville B-cycle  1051778.0  Non-RFID Card Member
# 3        8270475.0  Nashville B-cycle  1051781.0  Non-RFID Card Member
# 4        8270489.0  Nashville B-cycle  1051784.0  Non-RFID Card Member
# 5        8270491.0  Nashville B-cycle  1051784.0  Non-RFID Card Member
# 6        8270544.0  Nashville B-cycle  1051791.0  Non-RFID Card Member
# 7        8270545.0  Nashville B-cycle  1051791.0  Non-RFID Card Member
# 8        8270550.0  Nashville B-cycle  1051792.0  Non-RFID Card Member
# 9        8270553.0  Nashville B-cycle  1051792.0  Non-RFID Card Member
# 10       8270554.0  Nashville B-cycle  1051792.0  Non-RFID Card Member
# 11       8270555.0  Nashville B-cycle  1051794.0  Non-RFID Card Member
# 12       8270560.0  Nashville B-cycle  1051795.0  Non-RFID Card Member
# 13       8270712.0  Nashville B-cycle  1051813.0  Non-RFID Card Member
# 14       8270737.0  Nashville B-cycle  1051794.0  Non-RFID Card Member
# 15       8270782.0  Nashville B-cycle   641776.0      RFID Card Member
# 16       8270783.0  Nashville B-cycle   642870.0      RFID Card Member
# 17       8270812.0  Nashville B-cycle  1051825.0  Non-RFID Card Member
# 18       8270828.0  Nashville B-cycle  1051828.0  Non-RFID Card Member
# 19       8270889.0  Nashville B-cycle  1051833.0  Non-RFID Card Member
# 20       8270893.0  Nashville B-cycle  1051834.0  Non-RFID Card Member
# 21       8270897.0  Nashville B-cycle  1051835.0  Non-RFID Card Member
# 22       8270925.0  Nashville B-cycle  1051842.0  Non-RFID Card Member
# 23       8270928.0  Nashville B-cycle  1051844.0  Non-RFID Card Member
# 24       8270934.0  Nashville B-cycle  1051845.0  Non-RFID Card Member
# 25       8270936.0  Nashville B-cycle  1051778.0  Non-RFID Card Member
# 26       8270940.0  Nashville B-cycle  1051847.0  Non-RFID Card Member
# 27       8270945.0  Nashville B-cycle  1051781.0  Non-RFID Card Member
# 28       8270967.0  Nashville B-cycle  1051850.0  Non-RFID Card Member
# 29       8270971.0  Nashville B-cycle  1051850.0  Non-RFID Card Member
# ...            ...                ...        ...                   ...
# 233182  16336140.0  Nashville B-cycle  1883043.0  Non-RFID Card Member
# 233183  16336140.0  Nashville B-cycle  1883043.0  Non-RFID Card Member
# 233184  18204783.0  Nashville B-cycle  2224648.0  Non-RFID Card Member
# 233185  13316076.0  Nashville B-cycle  1478271.0  Non-RFID Card Member
# 233186  17201841.0  Nashville B-cycle  2033957.0  Non-RFID Card Member
# 233187  13316081.0  Nashville B-cycle  1478274.0  Non-RFID Card Member
# 233188  14495058.0  Nashville B-cycle  1588422.0  Non-RFID Card Member
# 233189  14495067.0  Nashville B-cycle  1588423.0  Non-RFID Card Member
# 233190  15997141.0  Nashville B-cycle  1832797.0  Non-RFID Card Member
# 233191  15997151.0  Nashville B-cycle  1832798.0  Non-RFID Card Member
# 233192  17201826.0  Nashville B-cycle  2033954.0  Non-RFID Card Member
# 233193  14720356.0  Nashville B-cycle  1517895.0  Non-RFID Card Member
# 233194  13316087.0  Nashville B-cycle  1478277.0  Non-RFID Card Member
# 233195  13316099.0  Nashville B-cycle  1478282.0  Non-RFID Card Member
# 233196  13316111.0  Nashville B-cycle  1478285.0  Non-RFID Card Member
# 233197  15072498.0  Nashville B-cycle  1667847.0  Non-RFID Card Member
# 233198  13316271.0  Nashville B-cycle  1478322.0  Non-RFID Card Member
# 233199  13316277.0  Nashville B-cycle  1478322.0  Non-RFID Card Member
# 233200  15072489.0  Nashville B-cycle  1667845.0  Non-RFID Card Member
# 233201  15072459.0  Nashville B-cycle  1666686.0  Non-RFID Card Member
# 233202  13316322.0  Nashville B-cycle  1478322.0  Non-RFID Card Member
# 233203  13316513.0  Nashville B-cycle  1478374.0  Non-RFID Card Member
# 233204  15074816.0  Nashville B-cycle  1668311.0  Non-RFID Card Member
# 233205  15074806.0  Nashville B-cycle  1668311.0  Non-RFID Card Member
# 233206  13316522.0  Nashville B-cycle  1478374.0  Non-RFID Card Member
# 233207  16326259.0  Nashville B-cycle  1881104.0  Non-RFID Card Member
# 233208  16326259.0  Nashville B-cycle  1881104.0  Non-RFID Card Member
# 233209  16326253.0  Nashville B-cycle  1881104.0  Non-RFID Card Member
# 233210  16326253.0  Nashville B-cycle  1881104.0  Non-RFID Card Member
# 233211  13317458.0  Nashville B-cycle   324355.0      RFID Card Member
#
#           UserCity UserState UserZip    UserCountry MembershipType  \
# 0              NaN       NaN   35242  UNITED STATES  24-Hour Kiosk
# 1              NaN       NaN   35242  UNITED STATES  24-Hour Kiosk
# 2              NaN       NaN   27612  UNITED STATES  24-Hour Kiosk
# 3              NaN       NaN    2116  UNITED STATES  24-Hour Kiosk
# 4              NaN       NaN   13815  UNITED STATES  24-Hour Kiosk
# 5              NaN       NaN   13815  UNITED STATES  24-Hour Kiosk
# 6              NaN       NaN   46227  UNITED STATES  24-Hour Kiosk
# 7              NaN       NaN   46227  UNITED STATES  24-Hour Kiosk
# 8              NaN       NaN   70706  UNITED STATES  24-Hour Kiosk
# 9              NaN       NaN   70706  UNITED STATES  24-Hour Kiosk
# 10             NaN       NaN   70706  UNITED STATES  24-Hour Kiosk
# 11             NaN       NaN   69209  UNITED STATES  24-Hour Kiosk
# 12             NaN       NaN     NaN  UNITED STATES  24-Hour Kiosk
# 13             NaN       NaN   92660  UNITED STATES  24-Hour Kiosk
# 14             NaN       NaN   69209  UNITED STATES  24-Hour Kiosk
# 15       Nashville        TN   37203  UNITED STATES         Annual
# 16       Nashville        IN   37203  UNITED STATES         Annual
# 17             NaN       NaN   37203  UNITED STATES  24-Hour Kiosk
# 18             NaN       NaN   37205  UNITED STATES  24-Hour Kiosk
# 19             NaN       NaN   37214  UNITED STATES  24-Hour Kiosk
# 20             NaN       NaN     NaN  UNITED STATES  24-Hour Kiosk
# 21             NaN       NaN   37214  UNITED STATES  24-Hour Kiosk
# 22             NaN       NaN   24073  UNITED STATES  24-Hour Kiosk
# 23             NaN       NaN   24073  UNITED STATES  24-Hour Kiosk
# 24             NaN       NaN   24073  UNITED STATES  24-Hour Kiosk
# 25             NaN       NaN   27612  UNITED STATES  24-Hour Kiosk
# 26             NaN       NaN   23451  UNITED STATES  24-Hour Kiosk
# 27             NaN       NaN    2116  UNITED STATES  24-Hour Kiosk
# 28             NaN       NaN   47720  UNITED STATES  24-Hour Kiosk
# 29             NaN       NaN   47720  UNITED STATES  24-Hour Kiosk
# ...            ...       ...     ...            ...            ...
# 233182         NaN       NaN   37208  UNITED STATES  24-Hour Kiosk
# 233183         NaN       NaN   37208  UNITED STATES  24-Hour Kiosk
# 233184         NaN       NaN   30030  UNITED STATES  24-Hour Kiosk
# 233185         NaN       NaN   43402  UNITED STATES  24-Hour Kiosk
# 233186         NaN       NaN   27408  UNITED STATES  24-Hour Kiosk
# 233187         NaN       NaN   43469  UNITED STATES  24-Hour Kiosk
# 233188         NaN       NaN   76051  UNITED STATES  24-Hour Kiosk
# 233189         NaN       NaN   29485  UNITED STATES  24-Hour Kiosk
# 233190         NaN       NaN    2127  UNITED STATES  24-Hour Kiosk
# 233191         NaN       NaN    6111  UNITED STATES  24-Hour Kiosk
# 233192         NaN       NaN     NaN  UNITED STATES  24-Hour Kiosk
# 233193         NaN       NaN   37214  UNITED STATES  24-Hour Kiosk
# 233194         NaN       NaN   43525  UNITED STATES  24-Hour Kiosk
# 233195         NaN       NaN   43402  UNITED STATES  24-Hour Kiosk
# 233196         NaN       NaN   43560  UNITED STATES  24-Hour Kiosk
# 233197         NaN       NaN   46804  UNITED STATES  24-Hour Kiosk
# 233198         NaN       NaN   37206  UNITED STATES  24-Hour Kiosk
# 233199         NaN       NaN   37206  UNITED STATES  24-Hour Kiosk
# 233200         NaN       NaN   46516  UNITED STATES  24-Hour Kiosk
# 233201  Fort Wayne        IN   46804  UNITED STATES        24-Hour
# 233202         NaN       NaN   37206  UNITED STATES  24-Hour Kiosk
# 233203         NaN       NaN   50111  UNITED STATES  24-Hour Kiosk
# 233204         NaN       NaN   91780  UNITED STATES  24-Hour Kiosk
# 233205         NaN       NaN   91780  UNITED STATES  24-Hour Kiosk
# 233206         NaN       NaN   50111  UNITED STATES  24-Hour Kiosk
# 233207         NaN       NaN   76063  UNITED STATES  24-Hour Kiosk
# 233208         NaN       NaN   76063  UNITED STATES  24-Hour Kiosk
# 233209         NaN       NaN   76063  UNITED STATES  24-Hour Kiosk
# 233210         NaN       NaN   76063  UNITED STATES  24-Hour Kiosk
# 233211   Nashville        TN   37206  UNITED STATES         Annual
#
#               Bike        ...           Day  YYYYMM ReturnDateLocal  \
# 0              783        ...           1.0  Jan-16          1/1/16
# 1       #PREDSBIKE        ...           1.0  Jan-16          1/1/16
# 2              497        ...           1.0  Jan-16          1/1/16
# 3              671        ...           1.0  Jan-16          1/1/16
# 4              783        ...           1.0  Jan-16          1/1/16
# 5              540        ...           1.0  Jan-16          1/1/16
# 6              764        ...           1.0  Jan-16          1/1/16
# 7              696        ...           1.0  Jan-16          1/1/16
# 8              716        ...           1.0  Jan-16          1/1/16
# 9              369        ...           1.0  Jan-16          1/1/16
# 10             942        ...           1.0  Jan-16          1/1/16
# 11             198        ...           1.0  Jan-16          1/1/16
# 12             942        ...           1.0  Jan-16          1/1/16
# 13             767        ...           1.0  Jan-16          1/1/16
# 14             198        ...           1.0  Jan-16          1/1/16
# 15             623        ...           1.0  Jan-16          1/1/16
# 16             919        ...           1.0  Jan-16          1/1/16
# 17             891        ...           1.0  Jan-16          1/1/16
# 18             286        ...           1.0  Jan-16          1/1/16
# 19             754        ...           1.0  Jan-16          1/1/16
# 20             314        ...           1.0  Jan-16          1/1/16
# 21              59        ...           1.0  Jan-16          1/1/16
# 22             343        ...           1.0  Jan-16          1/1/16
# 23             537        ...           1.0  Jan-16          1/1/16
# 24               2        ...           1.0  Jan-16          1/1/16
# 25             497        ...           1.0  Jan-16          1/1/16
# 26             521        ...           1.0  Jan-16          1/1/16
# 27             671        ...           1.0  Jan-16          1/1/16
# 28             764        ...           1.0  Jan-16          1/1/16
# 29             696        ...           1.0  Jan-16          1/1/16
# ...            ...        ...           ...     ...             ...
# 233182        2158        ...           6.0  Nov-17         11/6/17
# 233183        2158        ...           6.0  Nov-17         11/6/17
# 233184         632        ...          10.0  Aug-18         8/10/18
# 233185         765        ...          31.0  Dec-16        12/31/16
# 233186         301        ...          28.0  Apr-18         4/28/18
# 233187          74        ...          31.0  Dec-16        12/31/16
# 233188         249        ...          19.0  Apr-17         4/19/17
# 233189         771        ...          19.0  Apr-17         4/19/17
# 233190         717        ...          21.0  Sep-17         9/21/17
# 233191         599        ...          21.0  Sep-17         9/21/17
# 233192        2159        ...          28.0  Apr-18         4/28/18
# 233193          84        ...           8.0  May-17          5/8/17
# 233194         696        ...          31.0  Dec-16        12/31/16
# 233195         818        ...          31.0  Dec-16        12/31/16
# 233196         812        ...          31.0  Dec-16        12/31/16
# 233197           2        ...          10.0  Jun-17         6/10/17
# 233198         437        ...          31.0  Dec-16        12/31/16
# 233199         667        ...          31.0  Dec-16        12/31/16
# 233200          59        ...          10.0  Jun-17         6/10/17
# 233201         198        ...          10.0  Jun-17         6/10/17
# 233202         722        ...          31.0  Dec-16        12/31/16
# 233203         498        ...          31.0  Dec-16        12/31/16
# 233204        ~158        ...          10.0  Jun-17         6/10/17
# 233205         817        ...          10.0  Jun-17         6/10/17
# 233206        1641        ...          31.0  Dec-16        12/31/16
# 233207         528        ...           5.0  Nov-17         11/5/17
# 233208         528        ...           5.0  Nov-17         11/5/17
# 233209        1456        ...           5.0  Nov-17         11/5/17
# 233210        1456        ...           5.0  Nov-17         11/5/17
# 233211         437        ...          31.0  Dec-16        12/31/16
#
#         CheckoutTimeLocal  Hour  ReturnTimeLocal TripOver30Mins  \
# 0                 8:50:46   8.0         10:10:26              Y
# 1                 8:51:34   8.0         14:06:36              Y
# 2                10:15:35  10.0         11:17:35              Y
# 3                10:16:44  10.0         11:17:31              Y
# 4                10:23:35  10.0         12:15:38              Y
# 5                10:24:20  10.0         12:15:41              Y
# 6                10:38:08  10.0         11:05:38              N
# 7                10:38:47  10.0         11:05:35              N
# 8                10:40:43  10.0         14:11:28              Y
# 9                10:41:28  10.0         12:00:38              Y
# 10               10:42:11  10.0         10:42:20              N
# 11               10:42:15  10.0         11:41:20              Y
# 12               10:43:35  10.0         12:00:38              Y
# 13               11:30:53  11.0         11:56:21              N
# 14               11:43:27  11.0         12:21:24              Y
# 15               11:53:53  11.0         12:07:56              N
# 16               11:53:58  11.0         12:07:59              N
# 17               11:59:32  11.0         13:12:15              Y
# 18               12:00:56  12.0         13:12:16              Y
# 19               12:10:37  12.0         13:05:57              Y
# 20               12:12:24  12.0         13:05:56              Y
# 21               12:13:12  12.0         13:05:33              Y
# 22               12:21:44  12.0         13:42:13              Y
# 23               12:23:17  12.0         12:46:48              N
# 24               12:24:54  12.0         12:46:43              N
# 25               12:24:57  12.0         13:13:38              Y
# 26               12:25:57  12.0         13:42:09              Y
# 27               12:26:31  12.0         13:13:44              Y
# 28               12:33:39  12.0         13:04:34              Y
# 29               12:34:20  12.0         13:04:32              N
# ...                   ...   ...              ...            ...
# 233182           17:42:09  17.0         16:51:00              Y
# 233183           17:42:09  17.0         16:51:00              Y
# 233184           16:42:34  16.0         15:53:20              Y
# 233185           13:41:49  13.0         14:05:07              N
# 233186            9:27:59   9.0          8:41:35              Y
# 233187           13:42:41  13.0         14:04:52              N
# 233188           15:03:20  15.0         14:18:36              Y
# 233189           15:04:21  15.0         14:19:15              Y
# 233190           10:27:02  10.0          9:42:43              Y
# 233191           10:27:48  10.0          9:42:43              Y
# 233192            9:26:41   9.0          8:41:29              Y
# 233193           18:47:50  18.0         18:03:04              Y
# 233194           13:43:27  13.0         14:05:37              N
# 233195           13:44:57  13.0         14:03:57              N
# 233196           13:46:00  13.0         14:04:01              N
# 233197           11:49:09  11.0         11:12:56              Y
# 233198           14:01:50  14.0         16:17:49              Y
# 233199           14:03:03  14.0         16:18:30              Y
# 233200           11:48:27  11.0         11:13:04              Y
# 233201           11:45:12  11.0         11:12:50              Y
# 233202           14:07:45  14.0         16:19:09              Y
# 233203           14:30:42  14.0         15:31:19              Y
# 233204           15:15:30  15.0         15:04:43              Y
# 233205           15:14:34  15.0         15:04:53              Y
# 233206           14:31:45  14.0         15:31:03              Y
# 233207           11:49:11  11.0         10:41:42              Y
# 233208           11:49:11  11.0         10:41:42              Y
# 233209           11:48:39  11.0         10:41:45              Y
# 233210           11:48:39  11.0         10:41:45              Y
# 233211           16:27:49  16.0         17:12:24              Y
#
#         LocalProgramFlag  TripRouteCategory    TripProgramName
# 0                      Y         Round Trip  Nashville B-cycle
# 1                      Y         Round Trip  Nashville B-cycle
# 2                      Y            One Way  Nashville B-cycle
# 3                      Y            One Way  Nashville B-cycle
# 4                      Y            One Way  Nashville B-cycle
# 5                      Y            One Way  Nashville B-cycle
# 6                      Y         Round Trip  Nashville B-cycle
# 7                      Y         Round Trip  Nashville B-cycle
# 8                      Y         Round Trip  Nashville B-cycle
# 9                      Y         Round Trip  Nashville B-cycle
# 10                     Y         Round Trip  Nashville B-cycle
# 11                     Y            One Way  Nashville B-cycle
# 12                     Y         Round Trip  Nashville B-cycle
# 13                     Y            One Way  Nashville B-cycle
# 14                     Y            One Way  Nashville B-cycle
# 15                     Y            One Way  Nashville B-cycle
# 16                     Y            One Way  Nashville B-cycle
# 17                     Y         Round Trip  Nashville B-cycle
# 18                     Y         Round Trip  Nashville B-cycle
# 19                     Y            One Way  Nashville B-cycle
# 20                     Y            One Way  Nashville B-cycle
# 21                     Y            One Way  Nashville B-cycle
# 22                     Y            One Way  Nashville B-cycle
# 23                     Y            One Way  Nashville B-cycle
# 24                     Y            One Way  Nashville B-cycle
# 25                     Y            One Way  Nashville B-cycle
# 26                     Y            One Way  Nashville B-cycle
# 27                     Y            One Way  Nashville B-cycle
# 28                     Y         Round Trip  Nashville B-cycle
# 29                     Y         Round Trip  Nashville B-cycle
# ...                  ...                ...                ...
# 233182                 Y            One Way  Nashville B-cycle
# 233183                 Y            One Way  Nashville B-cycle
# 233184                 Y         Round Trip  Nashville B-cycle
# 233185                 Y         Round Trip  Nashville B-cycle
# 233186                 Y         Round Trip  Nashville B-cycle
# 233187                 Y         Round Trip  Nashville B-cycle
# 233188                 Y            One Way  Nashville B-cycle
# 233189                 Y            One Way  Nashville B-cycle
# 233190                 Y         Round Trip  Nashville B-cycle
# 233191                 Y         Round Trip  Nashville B-cycle
# 233192                 Y         Round Trip  Nashville B-cycle
# 233193                 Y            One Way  Nashville B-cycle
# 233194                 Y         Round Trip  Nashville B-cycle
# 233195                 Y         Round Trip  Nashville B-cycle
# 233196                 Y         Round Trip  Nashville B-cycle
# 233197                 Y            One Way  Nashville B-cycle
# 233198                 Y         Round Trip  Nashville B-cycle
# 233199                 Y         Round Trip  Nashville B-cycle
# 233200                 Y            One Way  Nashville B-cycle
# 233201                 Y            One Way  Nashville B-cycle
# 233202                 Y         Round Trip  Nashville B-cycle
# 233203                 Y         Round Trip  Nashville B-cycle
# 233204                 Y            One Way  Nashville B-cycle
# 233205                 Y            One Way  Nashville B-cycle
# 233206                 Y         Round Trip  Nashville B-cycle
# 233207                 Y            One Way  Nashville B-cycle
# 233208                 Y            One Way  Nashville B-cycle
# 233209                 Y            One Way  Nashville B-cycle
# 233210                 Y            One Way  Nashville B-cycle
# 233211                 Y         Round Trip  Nashville B-cycle
#
# [233212 rows x 36 columns]

# %% [markdown]
# Lets familiarize with the data contents by checking what are the contents of the data:

# %%
data.columns
# Out:
# Index(['TripId', 'UserProgramName', 'UserId', 'UserRole', 'UserCity',
#        'UserState', 'UserZip', 'UserCountry', 'MembershipType', 'Bike',
#        'BikeType', 'CheckoutKioskName', 'ReturnKioskName', 'DurationMins',
#        'AdjustedDurationMins', 'UsageFee', 'AdjustmentFlag', 'Distance',
#        'EstimatedCarbonOffset', 'EstimatedCaloriesBurned', 'CheckoutDateLocal',
#        'HighTemp', 'LoTemp', 'Precip', 'Month', 'Year', 'Day', 'YYYYMM',
#        'ReturnDateLocal', 'CheckoutTimeLocal', 'Hour', 'ReturnTimeLocal',
#        'TripOver30Mins', 'LocalProgramFlag', 'TripRouteCategory',
#        'TripProgramName'],
#       dtype='object')

# %% [markdown]
# Now that we have read our data into memory, we can begin the data analysis and answering the questions that interests us, we would be answering the first part of the questions as a business consultant and then the second tier as a user of the service, so we would divide our problem in two tiers.

# %% [markdown]
# ### Part A - Business Consultant
#
# As a business consultant to a ride share company, we want to apply our data science skills to find insights and answers to some questions that we believe may guide decision making process, help maximize clients profit, reduce cost and grant users or the customers maximum satisfaction.

# %% [markdown]
# ###  Problem 1

# %% [markdown]
# __What are the checkout and return kiosks with highest usage rate.__

# %% [markdown]
# Here we are interested in knowing the checkout and return kiosk with the highest usage, this is to possibly answer for the need of ensuring more provision of bicycles in such area so as to make sure that we give maximum satisfaction to our customers.
#
# I used the count of the users that checkout in this location in the data collected as the means to get the solution to this problem.

# %%
# This is the solution to the Checkout kiosk
checkout = dict(data['CheckoutKioskName'])
returnKiosk = dict(data['ReturnKioskName'])
checkoutCounts  = {}
for checkoutKiosk in checkout.values():
    checkoutCounts[checkoutKiosk] = checkoutCounts.get(checkoutKiosk,0)+1
from operator import itemgetter
topCheckoutpts = sorted(checkoutCounts.items(), key = itemgetter(1), reverse = True)
topFivepts = pd.DataFrame(topCheckoutpts[:5], columns = ['CheckoutKiosk', 'UsageRate'])
topFivepts
# Out:
#                                     CheckoutKiosk  UsageRate
# 0  Shelby Bottoms Nature Center: 1900 Davidson St      25655
# 1                     Centennial Park: 27th Ave N      18659
# 2                                      Parthenon       14066
# 3       Two Rivers Skatepark: Two Rivers Greenway      12564
# 4        Riverfront Station: Broadway & 1st Ave N      11529

# %%
topFivepts.plot(x = topFivepts['CheckoutKiosk'],kind = "barh", rot = 0, title = "Top 5 checkout points")
plt.show()

# %% [markdown]
# We observed from the above solution the top five checkout points in our data, and we see that Shelby Bottoms Nature Center-1900 Davidson Str has the highest checkpout rate.

# %%
rkioskCounts = {}
for rkiosk in returnKiosk.values():
    rkioskCounts[rkiosk] = rkioskCounts.get(rkiosk,0)+1
from operator import itemgetter
returnKioskpts = sorted(rkioskCounts.items(), key = itemgetter(1), reverse = True)
topFivereturnKiosk = pd.DataFrame(returnKioskpts[:5], columns = ['ReturnKiosk', 'Rate'])
topFivereturnKiosk
# Out:
#                                       ReturnKiosk   Rate
# 0  Shelby Bottoms Nature Center: 1900 Davidson St  25564
# 1                     Centennial Park: 27th Ave N  17489
# 2        Riverfront Station: Broadway & 1st Ave N  15384
# 3                                      Parthenon   13794
# 4       Two Rivers Skatepark: Two Rivers Greenway  12302

# %%
topFivepts.plot(x = topFivereturnKiosk['ReturnKiosk'],kind = "barh", rot = 0, title = "Top 5 Return Kiosk")
plt.show()

# %% [markdown]
# #### Output Explanation
# Its interesting to note that we also have the same kiosk name reappearing as the highest return kiosk, this makes sense because we know for the most part that most people would return a bicycle to the exact location where they took it from, but we observe that the checkout and return do not have the same value, this is because there are cases where people take a bicycle from a point A and return it to another point.
#
# A case scenario might be in a place like Nashville, the Music City where we have several tourist attraction, a tourist might park his vehicle in a different location and choose to ride a bicycle to the  closest location to his parking lot.

# %% [markdown]
# #### Code Explanation
# The CheckoutKioskName and ReturnKioskName were read into a dictionary using the dict function,
#
# The .values() and .get() was used to get the value and count of occurencies for CheckoutKioskName and ReturnKioskName.
#
# The returnKioskpts and Checkoutpts values were sorted in a decending order using reverse='true'
#
# And finally,we used slicing (:5) to get the top 5 and then using  dataframe to represent the output.
#
# For the plots, .plot() function was used to make bar plots using the ReturnKiosk and CheckoutKiosk on the Vertical axis and Usage on the Horizontal axis

# %% [markdown]
# ### Problem 2

# %% [markdown]
# __What is the average trip duration.__

# %%
tripDuration = data['DurationMins']
print("The average duration is ",tripDuration.mean(),"minutes")
# Out:
# The average duration is  51.50831861139221 minutes

# %% [markdown]
# We would want to see an histogram to see the spread or the distribution of the trip duration and see how well our solution did in measuring the average trip duration

# %%
tripDuration.describe()
# Out:
# count    233212.000000
# mean         51.508319
# std          69.009707
# min           0.000000
# 25%          19.000000
# 50%          39.000000
# 75%          61.000000
# max        1434.000000
# Name: DurationMins, dtype: float64

# %%
plt.hist(tripDuration, range = (0,200), bins = 16)
plt.title('Distribution of Trip Durations')
plt.xlabel("Time in Minutes")
plt.ylabel("Trip Duration in Minutes")
plt.show()

# %% [markdown]
# #### Output Explanation
# I observed that the duration is left skewed, as most of the people ride less than 2 hours, we also found out from our summary statistics that the average trip duration is 51.51 minutes.

# %% [markdown]
# #### Code Explanation
# The tripDuration variable was used to store the values in the DurationMins column, and the .mean() was used to get the avaerage trip duration.
#
# Also, the .describe() was used tio generate the statistical summary for trip duration.
#
# Finally, plt.hist() function was used to make a an histogram for the distribution of trip duration

# %% [markdown]
# ### Problem 3

# %% [markdown]
# __For an annual award ceremony, we like to know the top 20 users with highest trip duration.__

# %%
userId = data['UserId']
tripDuration = data['DurationMins']

# We observed that the dataFrame recorded the userID as float, so we had to convert to integer for
# our intended purpose
userd =[int(i) for i in userId]
userTrip = list(zip(userd,tripDuration))

import operator 
topTripDur = sorted(userTrip, key=operator.itemgetter(1), reverse = True)
top20TripDuration = pd.DataFrame(topTripDur[:20], columns = ['userID', 'tripDuration'])
top20TripDuration
# Out:
#      userID  tripDuration
# 0   1440361        1434.0
# 1   1881104        1433.0
# 2   1881104        1433.0
# 3   1411875        1432.0
# 4   1881104        1432.0
# 5   1881104        1432.0
# 6   1668311        1430.0
# 7   1668311        1429.0
# 8   1225862        1418.0
# 9   1121512        1415.0
# 10  1666686        1407.0
# 11  1667845        1405.0
# 12  1275465        1404.0
# 13  1275467        1404.0
# 14  1667847        1403.0
# 15  1457424        1400.0
# 16  1457424        1400.0
# 17  1271446        1398.0
# 18  1517895        1396.0
# 19  1225547        1395.0

# %% [markdown]
# #### Output Explanation
# Here I was able to get the top 20 users with highest trip duration, this is important because the business owner may want to give award or a form of compensation to encourage regular customers.

# %% [markdown]
# #### Code Explanation
# UserID and tripDaration was used to store the values of UserID and Durationmins respectively.
#
# zip() was used to map UserID and tripDaration together and then passed into a list.
#
# operator was imported inorder to use the itemgetter to their counts in a descending order by setting rever='true' and
# then using slicing (:20) to get the top twenty values passed through DataFrame.

# %% [markdown]
#  ### Problem 4

# %% [markdown]
# __What is the average calories burned?__
#
# '''
# The exact number of calories burned during a bike ride can be difficult to gauge. On average, a 180 lb. cyclist riding at a moderate effort level will burn approximately 650 calories per hour.
# '''

# %%
avgCaloriesBurned = data['EstimatedCaloriesBurned']
print("The average calories burned is ",avgCaloriesBurned.mean(), "calories per minute")
# Out:
# The average calories burned is  261.08144092070734 calories per minute

# %%
avgCaloriesBurned.describe()
# Out:
# count    233212.000000
# mean        261.081441
# std         196.985840
# min           0.000000
# 25%         106.000000
# 50%         228.000000
# 75%         360.000000
# max        3810.000000
# Name: EstimatedCaloriesBurned, dtype: float64

# %%
plt.hist(avgCaloriesBurned, range = (0,700), bins = 16)
plt.title('Average calories burned')
plt.xlabel("Time in Minutes")
plt.ylabel("Trip Duration in Minutes")
plt.show()

# %% [markdown]
# #### Result Explanation
# Consistent high average calories burned indicate that the bikes are in good shape and the customers are
# also using the service. As a business consultant, this is an important information to take note of

# %% [markdown]
# #### Code Explanation
# The avgCaloriesBurned variable was used to store the values in the EstimatedCaloriesBurned column, and the .mean() was used to get the avaerage trip duration.
#
# Also, the .describe() was used tio generate the statistical summary for avgCaloriesBurned.
#
# Finally, plt.hist() function was used to make a an histogram to visualise the distribution of the average calories burned

# %% [markdown]
# ### Problem 5

# %% [markdown]
# __What day of the week has the highest pickup rate?__

# %%
import datetime
checkoutdate = data['CheckoutDateLocal']
#day_week = [df[date_column].dt.weekday_name]
checkout = list(checkoutdate)
day_week =[datetime.datetime.strptime(x, '%m/%d/%y').strftime('%A') for x in checkout]
days = set(day_week)
for day in days:
    cnt = day_week.count(day)
    print("{} appears {} times".format(day,cnt))
# Out:
# Wednesday appears 23250 times
# Sunday appears 48174 times
# Saturday appears 52365 times
# Tuesday appears 25378 times
# Friday appears 31110 times
# Monday appears 29195 times
# Thursday appears 23740 times

# %%
df = pd.DataFrame(day_week, columns = ["weekDay"] )
dfCnt = pd.value_counts(df['weekDay'].values, sort=False)
dfCnt.plot(kind = "bar", title = "WeekDay with Highest Pickup Rate")
plt.show()

# %% [markdown]
# #### Result Explanation
# From the output and the plot, we can observe that Saturday has the highest pickup rate followed by Sunday
# and then Friday. This is telling us that people go out for bike riding on weekends which is realistic.
# As a business consultant,this is the best period to introduce any new product since we have more customers during this period.
#
# Also adequate planning can be made interms of number of bikes, bike accessories, etc

# %% [markdown]
# #### Code explanation
# The datetime function was used to convert the checkoutdate format and using a for loop to get the days of the week in the checkoutdate and then using the set function to get the unique day of the week.
#
# We use the .count() to get the number of occurences of the days of the week
# Finally, Plot was used to make a barchat for pickup rate versus week day

# %% [markdown]
# ### 6. what season of the year has the highest trip duration?

# %%
df = data['Month']
Df = [int(i) for i in df]
DF = pd.DataFrame(Df)
seasonDur = DF[0]
#Create a Seasonal Dictionary that will map months to seasons
SeasonDict = {11:'Winter',12:'Winter',1:'Winter',2:'Spring',3:'Spring',4:'Spring',5:'Summer',6:'Summer',7:'Summer',
8:'Autumn',9:'Autumn',10: 'Autumn'}
mont = seasonDur.map(lambda x:SeasonDict[x])
tripDur = data['DurationMins']

seasonDf = pd.DataFrame(
    {'season':mont,
     'DurationMin':tripDur})
seasonDf
# Call the function with the groupby operation. 
Grouped = seasonDf.groupby(['season'])
Grouped.agg(['mean','sum', 'std','count'])
# Out:
#        DurationMin
#               mean        sum        std  count
# season
# Autumn   50.562584  3308411.0  64.506530  65432
# Spring   51.986329  3076343.0  66.924626  59176
# Summer   53.436606  4261035.0  72.003000  79740
# Winter   47.345101  1366569.0  74.234260  28864

# %% [markdown]
# 7. what time has the highest pickup rate

# %%
# We are interested in looking at the hour of the day that has the highest pickup rate, this is to help a user know an estimate
# of what hour the bikes would most probably have been checked-out
import datetime
checkoutHour = data['Hour']
checkout = list(checkoutHour)
    
checkoutTimedf = pd.DataFrame(checkout, columns = ["Hour"] )
checkoutdfCnt = pd.value_counts(checkoutTimedf['Hour'].values, sort=True)
checkoutdfCnt.plot(kind = "bar", title = "Hour with Highest Pickup Rate")
plt.show()

# %% [markdown]
# 8. What is the statistics of the zip codes with kiosk present?

# %%
zipCodes = data['UserZip']
checkoutKiosk = data['CheckoutKioskName']
returnKiosk = data['ReturnKioskName']

zipcodesKiosk = list(zip(zipCodes,checkoutKiosk,returnKiosk))
df = pd.DataFrame(zipcodesKiosk)
df
# Out:
#             0                                                  1  \
# 0       35242                     SoBro: 3rd Ave S & Symphony Pl
# 1       35242                     SoBro: 3rd Ave S & Symphony Pl
# 2       27612                        Centennial Park: 27th Ave N
# 3        2116                        Centennial Park: 27th Ave N
# 4       13815                     SoBro: 3rd Ave S & Symphony Pl
# 5       13815                     SoBro: 3rd Ave S & Symphony Pl
# 6       46227                        Centennial Park: 27th Ave N
# 7       46227                        Centennial Park: 27th Ave N
# 8       70706                          Trolley Barns: Peabody St
# 9       70706                          Trolley Barns: Peabody St
# 10      70706                          Trolley Barns: Peabody St
# 11      69209     Walk of Fame Park: 5th Ave S  & Demonbreun St.
# 12        NaN                          Trolley Barns: Peabody St
# 13      92660            Frist Center: 9th Ave S & Demonbreun St
# 14      69209          Two Rivers Skatepark: Two Rivers Greenway
# 15      37203             Sevier Park: Kirkwood Ave & 12th Ave S
# 16      37203             Sevier Park: Kirkwood Ave & 12th Ave S
# 17      37203          Two Rivers Skatepark: Two Rivers Greenway
# 18      37205          Two Rivers Skatepark: Two Rivers Greenway
# 19      37214     Shelby Bottoms Nature Center: 1900 Davidson St
# 20        NaN     Shelby Bottoms Nature Center: 1900 Davidson St
# 21      37214     Shelby Bottoms Nature Center: 1900 Davidson St
# 22      24073               Downtown YMCA: Church St & 9th Ave N
# 23      24073               Downtown YMCA: Church St & 9th Ave N
# 24      24073               Downtown YMCA: Church St & 9th Ave N
# 25      27612                    The Gulch: 11th Ave S & Pine St
# 26      23451               Downtown YMCA: Church St & 9th Ave N
# 27       2116                    The Gulch: 11th Ave S & Pine St
# 28      47720                        Centennial Park: 27th Ave N
# 29      47720                        Centennial Park: 27th Ave N
# ...       ...                                                ...
# 233182  37208           Riverfront Station: Broadway & 1st Ave N
# 233183  37208           Riverfront Station: Broadway & 1st Ave N
# 233184  30030           Riverfront Station: Broadway & 1st Ave N
# 233185  43402          Two Rivers Skatepark: Two Rivers Greenway
# 233186  27408                        Centennial Park: 27th Ave N
# 233187  43469          Two Rivers Skatepark: Two Rivers Greenway
# 233188  76051     Shelby Bottoms Nature Center: 1900 Davidson St
# 233189  29485     Shelby Bottoms Nature Center: 1900 Davidson St
# 233190   2127  Fifth Third Plaza: Church St between 4th & 5th...
# 233191   6111  Fifth Third Plaza: Church St between 4th & 5th...
# 233192    NaN                        Centennial Park: 27th Ave N
# 233193  37214  Cumberland Park: Victory Way at Base of Pedest...
# 233194  43525          Two Rivers Skatepark: Two Rivers Greenway
# 233195  43402          Two Rivers Skatepark: Two Rivers Greenway
# 233196  43560          Two Rivers Skatepark: Two Rivers Greenway
# 233197  46804                              Gay St. and 1st Ave N
# 233198  37206     Shelby Bottoms Nature Center: 1900 Davidson St
# 233199  37206     Shelby Bottoms Nature Center: 1900 Davidson St
# 233200  46516                              Gay St. and 1st Ave N
# 233201  46804                              Gay St. and 1st Ave N
# 233202  37206     Shelby Bottoms Nature Center: 1900 Davidson St
# 233203  50111  Fifth Third Plaza: Church St between 4th & 5th...
# 233204  91780            Frist Center: 9th Ave S & Demonbreun St
# 233205  91780            Frist Center: 9th Ave S & Demonbreun St
# 233206  50111  Fifth Third Plaza: Church St between 4th & 5th...
# 233207  76063                          Trolley Barns: Peabody St
# 233208  76063                          Trolley Barns: Peabody St
# 233209  76063                          Trolley Barns: Peabody St
# 233210  76063                          Trolley Barns: Peabody St
# 233211  37206     Shelby Bottoms Nature Center: 1900 Davidson St
#
#                                                         2
# 0                          SoBro: 3rd Ave S & Symphony Pl
# 1                          SoBro: 3rd Ave S & Symphony Pl
# 2                         The Gulch: 11th Ave S & Pine St
# 3                         The Gulch: 11th Ave S & Pine St
# 4          Walk of Fame Park: 5th Ave S  & Demonbreun St.
# 5          Walk of Fame Park: 5th Ave S  & Demonbreun St.
# 6                             Centennial Park: 27th Ave N
# 7                             Centennial Park: 27th Ave N
# 8                               Trolley Barns: Peabody St
# 9                               Trolley Barns: Peabody St
# 10                              Trolley Barns: Peabody St
# 11              Two Rivers Skatepark: Two Rivers Greenway
# 12                              Trolley Barns: Peabody St
# 13         Walk of Fame Park: 5th Ave S  & Demonbreun St.
# 14      Cumberland Park: Victory Way at Base of Pedest...
# 15                        The Gulch: 11th Ave S & Pine St
# 16                        The Gulch: 11th Ave S & Pine St
# 17              Two Rivers Skatepark: Two Rivers Greenway
# 18              Two Rivers Skatepark: Two Rivers Greenway
# 19              Two Rivers Skatepark: Two Rivers Greenway
# 20              Two Rivers Skatepark: Two Rivers Greenway
# 21              Two Rivers Skatepark: Two Rivers Greenway
# 22                            Centennial Park: 27th Ave N
# 23                            Centennial Park: 27th Ave N
# 24                            Centennial Park: 27th Ave N
# 25         Shelby Bottoms Nature Center: 1900 Davidson St
# 26                            Centennial Park: 27th Ave N
# 27         Shelby Bottoms Nature Center: 1900 Davidson St
# 28                            Centennial Park: 27th Ave N
# 29                            Centennial Park: 27th Ave N
# ...                                                   ...
# 233182        Morgan Park: Magdeburg Greenway & 4th Ave N
# 233183        Morgan Park: Magdeburg Greenway & 4th Ave N
# 233184           Riverfront Station: Broadway & 1st Ave N
# 233185          Two Rivers Skatepark: Two Rivers Greenway
# 233186                        Centennial Park: 27th Ave N
# 233187          Two Rivers Skatepark: Two Rivers Greenway
# 233188  J. Percy Priest Dam Trailhead: Stones River Gr...
# 233189  J. Percy Priest Dam Trailhead: Stones River Gr...
# 233190  Fifth Third Plaza: Church St between 4th & 5th...
# 233191  Fifth Third Plaza: Church St between 4th & 5th...
# 233192                        Centennial Park: 27th Ave N
# 233193                Public Square: 3rd Ave N & Union St
# 233194          Two Rivers Skatepark: Two Rivers Greenway
# 233195          Two Rivers Skatepark: Two Rivers Greenway
# 233196          Two Rivers Skatepark: Two Rivers Greenway
# 233197     Walk of Fame Park: 5th Ave S  & Demonbreun St.
# 233198     Shelby Bottoms Nature Center: 1900 Davidson St
# 233199     Shelby Bottoms Nature Center: 1900 Davidson St
# 233200     Walk of Fame Park: 5th Ave S  & Demonbreun St.
# 233201     Walk of Fame Park: 5th Ave S  & Demonbreun St.
# 233202     Shelby Bottoms Nature Center: 1900 Davidson St
# 233203  Fifth Third Plaza: Church St between 4th & 5th...
# 233204                     SoBro: 3rd Ave S & Symphony Pl
# 233205                     SoBro: 3rd Ave S & Symphony Pl
# 233206  Fifth Third Plaza: Church St between 4th & 5th...
# 233207           Riverfront Station: Broadway & 1st Ave N
# 233208           Riverfront Station: Broadway & 1st Ave N
# 233209           Riverfront Station: Broadway & 1st Ave N
# 233210           Riverfront Station: Broadway & 1st Ave N
# 233211     Shelby Bottoms Nature Center: 1900 Davidson St
#
# [233212 rows x 3 columns]

# %% [markdown]
# 9.	What is the statictic of membershipType used by riders

# %%
membershipTypes=data['MembershipType']
membershipTypeList=list(membershipTypes)
membership=set(membershipTypeList)

for membershipType in membership:
    count = membershipTypeList.count(membershipType)
    print("{} rider(s) uses: {} Membership type".format(count,membershipType))
# Out:
# 14 rider(s) uses: Republic Rider (Annual) Membership type
# 1 rider(s) uses: annual Membership type
# 2 rider(s) uses: Local365+Guest Pass Membership type
# 31 rider(s) uses: Founding Member Membership type
# 2 rider(s) uses: Annual Member Membership type
# 7506 rider(s) uses: 24-Hour Membership type
# 47 rider(s) uses: Annual Plus Membership type
# 2 rider(s) uses: U.T. Student Membership Membership type
# 4421 rider(s) uses: 30-Day Membership type
# 39571 rider(s) uses: Annual Membership type
# 38 rider(s) uses: Annual Membership Membership type
# 11 rider(s) uses: Denver B-cycle Founder Membership type
# 9224 rider(s) uses: 7-Day Membership type
# 26 rider(s) uses: Annual Pass Membership type
# 172268 rider(s) uses: 24-Hour Kiosk Membership type
# 46 rider(s) uses: Local365 Membership type
# 2 rider(s) uses: APSU Student Membership type

# %% [markdown]
# 10. What is the average carbon offset

# %%
carbonOffset=data['EstimatedCarbonOffset']
print("The average estimated carbonOffset is ",carbonOffset.mean(), "calories per minute")
# Out:
# The average estimated carbonOffset is  6.20341706259067 calories per minute
